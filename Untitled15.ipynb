# %% [markdown]
# <a href="https://colab.research.google.com/github/Drtuto2027/encapsulamiento/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Estudiante:
    def __init__(self, nombre):
        self.nombre = nombre

class Curso:
    def __init__(self, nombre):
        self.nombre = nombre
        # Lista de estudiantes, que existen independientemente del curso
        self.estudiantes = []

    def agregar_estudiante(self, estudiante):
        self.estudiantes.append(estudiante)

    def listar_estudiantes(self):
        print(f"Curso: {self.nombre}")
        for estudiante in self.estudiantes:
            print(f" - {estudiante.nombre}")

# Crear estudiantes independientemente del curso
estudiante1 = Estudiante("Juan")
estudiante2 = Estudiante("Ana")

# Crear un curso y agregar estudiantes al curso
curso = Curso("Matemáticas")
curso.agregar_estudiante(estudiante1)
curso.agregar_estudiante(estudiante2)
curso.listar_estudiantes()
# Out:
# Curso: Matemáticas
#  - Juan
#  - Ana

# %% [markdown]
# #ejercicio agregación
